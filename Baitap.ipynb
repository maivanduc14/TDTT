# %%
n = int(input())
tong=''
t=''
k=''
m=''
for i in range(1,n+1):
    print(i,end=' ')
print()
for i in range(n,-1,-1):
    print (i,end=' ')
print()
for i in range (2,n+1,2):
    print(i,end=' ')
print()
for i in range(1,n+1,2):
    print(i,end=' ')
print()
for i in range(4,n+1,4):
    print(i,end=' ')
print()
for i in range(n):
    print (chr(97+i),end=' ')
print()
for i in range(n):
    print (chr(97+26-n+i),end=' ')
# Out:
# 1 2 3 4 5 6 7 8
# 8 7 6 5 4 3 2 1 0
# 2 4 6 8
# 1 3 5 7
# 4 8
# a b c d e f g h
# s t u v w x y z

# %%
n = int(input())
tong=0
for i in range(3,n+1,3):
    tong=tong+i
print(tong)
# Out:
# 30

# %%
n = int(input())
tong=0
for i in range(1,n+1):
    tong=tong+1/(2*i)
print (tong)
# Out:
# 7.193281886960333
