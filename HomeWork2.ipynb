# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó.

# %%
a ,b = map (int,input().split())
print(a*b , (a+b)*2)
# Out:
# 20 18

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
r = int(input())
print(3.14*r**2,2*3.14*r)
# Out:
# 28.26 18.84

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình

# %%
a, b , c = map(int,input().split())
if (a+b>c and a+c>b and b+c>a):
    if (a==b==c):
        print("Là tam giác đều")
    elif (a==b or a==c or b==c):
        print("Là tam giác cân")
    elif (a**2+b**2==c**2 or a**2+c**2==b**2 or b**2+c**2==a**2):
        print("Là tam giác vuông ")
    else:
        print("Là tam giác thường ")
    cv=(a+b+c)/2
    s=cv*(cv-a)*(cv-b)*(cv-c)**0.5
    print(f"{s:.2f},{cv*2:.2f}")

else :
    print("Khong la ba canh cua mot tam giac")
# Out:
# Là tam giác cân
# 24.31,11.00

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a , b = map(int,input().split())
print(f"    {a}.x + {b} = 0")
print(f"<=> x = {-b}/{a}")
print("<=> x =",-b/a)
# Out:
#     4.x + 5 = 0
# <=> x = -5/4
# <=> x = -1.25

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a ,b ,c = map(int, input().split())
denta = b**2 -4*a*c
if (denta < 0 ):
    print("Phương trình vô nghiệm ")
elif (denta == 0):
    x= (-b)/(2*a)
    print (f"x = {x}")
else :
    x1 = ((-b)+denta**0.5)/(2*a)
    x2 = ((-b)-denta**0.5)/(2*a)
    print(f"x1 = {x1}")
    print(f"x2 = {x2}")
# Out:
# x = 2.0

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c,d được nhập từ bàn phím).

# %%
a , b ,c ,d = map(int,input().split())
ln1=max(a,b)
ln2=max(c,d)
print(max(ln1,ln2))
# Out:
# 5

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, d được nhập từ bàn phím).

# %%
a , b ,c ,d = map (int,input().split())
m1=min(a,b)
m2=min(c,d)
print(min(m1,m2))
# Out:
# 1

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax  by  m
# cx  dy  n

# %%
a , b ,m ,c ,d , n = map(int,input().split())
sc=a/c
d = d*sc 
n = n*sc
b = b - d 
m = m - n 
y = m/b
x = (n-d*y)/a
print(x,y)
# Out:
# 0.09090909090909091 0.2727272727272727

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
a = int (input())
gio = a//3600
a = a-gio*3600
phut = a //60
giay = a - phut*60
print (f'{gio} giờ {phut} phút {giay} giây')
# Out:
# 2 giờ 31 phut 40 giay

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
a , b = map (int,input().split())
r = int(input())
c , d = map(int,input().split())
rm = ((a-c)**2+(b-d)**2)**0.5
if (rm==r):
    print(f"A({c},{d}) thuộc đường tròn tâm O({a},{b}) bán kính {r}")
else :
    print(f"A({c},{d}) không thuộc đường tròn tâm O({a},{b}) bán kính {r}")
# Out:
# A(3,4) thuộc đường tròn tâm O(0,0) bán kính 5

# %% [markdown]
# Bài 11: Tính x
# y (Với x, y là số thực).

# %%
x, y = map(float,input().split())
print(x**y)
# Out:
# 8.0
