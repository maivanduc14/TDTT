# %% [markdown]
# W2A1

# %%
print("Hello World!")

# %% [markdown]
# W2A2

# %%
n= input()
print(f"Hello {n}!")
# Out:
# Hello ĐỨc!

# %% [markdown]
# W2A3

# %%
a , b = map(int,input().split())
print(f"{a} + {b} = {a+b}")
print(f"{a} - {b} = {a-b}")
print(f"{a} * {b} = {a*b}")
print(f"{a} // {b} = {a//b}")
print(f"{a} % {b} = {a%b}")
print(f"{a} / {b} = {a/b:.2f}")
# Out:
# 3 + 5 = 8
# 3 - 5 = -2
# 3 * 5 = 15
# 3 // 5 = 0
# 3 % 5 = 3
# 3 / 5 = 0.60

# %% [markdown]
# W2A4

# %%
a , b , c , d ,e ,f = map (float,input().split())
tb = ((a+b+c)+(d+e)*2+f*3)/10
print(f"{tb:.1f}")
# Out:
# 4.2

# %% [markdown]
# W2A5

# %%
a ,b = map(int, input().split())
print(a**b)
# Out:
# 8

# %% [markdown]
# W2A6

# %%
s = input()
print(ord(s))
print(s.upper())
# Out:
# 115
# S

# %% [markdown]
# W2A7

# %%
a=((13**2)*3)+5
b=13**2*3+5
print(a)
print(b)
# Out:
# 512
# 512

# %% [markdown]
# W2A8

# %%
c = float(input())
f = 9/5*c+32
print(f"{f:.2f}")
# Out:
# 77.00

# %% [markdown]
# W2A9

# %%
x = float(input())
tong = x + 10 + 0.3*x + 0.1*x
print(f"{tong:.2f}")
# Out:
# 24.00

# %% [markdown]
# W2A10

# %%
n = input()
n=n.split()
print(f"Hi {n[2]}, {n[1]} and {n[0]}.")
# Out:
# Hi Helen, Ailce and Bob

# %% [markdown]
# W2A11

# %%
a , b = map(int,input().split())
c = a*3600 + b*60
print(c)
# Out:
# 9600

# %% [markdown]
# W2A12

# %%
n = int (input())
print(f"Cần {6*n**2} miếng dán")
# Out:
# Cần 54 miếng dán

# %% [markdown]
# W2A13

# %%
a , b = map(int, input().split())
tich = (a*b)%10
print(tich)
# Out:
# 5

# %% [markdown]
# W2A14

# %%
a , b =map (int,input().split())
a ,b = b ,a
print(a,b)
# Out:
# 4 3

# %% [markdown]
# W2A15

# %%
n = int(input())
t=''
for i in range(n):
    t = t +'*'
print(t)
# Out:
# ******

# %% [markdown]
# W2A16

# %%
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# W2A17

# %%
n = ''
for i in range(3):
    n=n+'*'
    print(n,'\n')
# Out:
# *
#
# **
#
# ***

# %% [markdown]
# W2A18

# %%
print ('### # #   ### ###')
print (' #  #  #   #  #')
print (' #  #   #  #  #')
print (' #  #  #   #  #')
print (' #  ##     #  #')
# Out:
# ### # #   ### ###
#  #  #  #   #  #
#  #  #   #  #  #
#  #  #  #   #  #
#  #  ##     #  #

# %% [markdown]
# W2A19

# %%
print("Monday\nTuesday\nWednesday\nThursday\nfriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# friday
# Saturday
# Sunday

# %% [markdown]
# W2A20

# %%
print("January")
print("February")
print("March")
print("April")
print("May")
print("June")
print("July")
print("August")
print("September")
print("October")
print("November")
print("December")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# W2A21

# %%
for i in range(10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
